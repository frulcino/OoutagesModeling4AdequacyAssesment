# %%
import powerplantmatching as pm
import math
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
from scipy.stats import expon
from scipy.optimize import curve_fit
from astropy.visualization import hist
#for fitting:
from scipy.stats import expon, rv_discrete
from scipy.optimize import curve_fit
from sklearn.neighbors import KernelDensity
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
#for plotting Markov Chain graph
import networkx as nx
import matplotlib.pyplot as plt


#helper functions

def import_df(path, cols = ['StartTS', 'EndTS', 'TimeZone', 'Status', 'Type', 'AreaCode',
       'AreaTypeCode', 'AreaName', 'MapCode', 'PowerResourceEIC', 'UnitName',
       'ProductionType', 'InstalledCapacity', 'AvailableCapacity',
       'Reason']):
    """
    imports and preprocess data_frame
    path: string containing path of csv file containing table
    cols: list of column names to select in df
    returns: non redundat dataframe with only failures
    """
    
    df = pd.read_csv(path, sep = "\t", parse_dates = [0,1])
    df = df[cols] #selects only column
    df = df.drop_duplicates(subset = ["UnitName","StartTS"]) #deletes redundant rows
    #df = df[(df["Reason"] == "Failure")] # WHERE | (df["Reason"] == 'Foreseen Maintenance')
    #maybe can do df[df["Reason"] in reasons]?
    return df

def get_week(date):
    """
    input: date in date_time format
    output: what week of the year the date corresponds to
    """
    return date.week


def truncate(number, digits) -> float:
    # Improve accuracy with floating point operations, to avoid truncate(16.4, 2) = 16.39 or truncate(-1.13, 2) = -1.12
    nbDecimals = len(str(number).split('.')[1]) 
    if nbDecimals <= digits:
        return number
    stepper = 10.0 ** digits
    return math.trunc(stepper * number) / stepper

def markov_graph(transitions, seed = 42, digits = 4, title = ""):
    """
    input: transitions, a dictionary having as 
    keys: touples with 2 elements being the from state and from state
    values: the transition probability
    output: markov chain graph
    """
    G = nx.MultiDiGraph()

    for transition, probability in transitions.items():
        state_from, state_to = transition
        if probability != 0: 
        #if probability state_from to state_to is not 0 we add an edge to the graph
            G.add_edge(state_from, state_to, weight=truncate(probability, digits))

    #create positions of nodes: dictionary with coordinates
    pos = nx.spring_layout(G, seed) 

    # Increase the scale to avoid overlap
    pos = {k: [v[0] * 2, v[1] * 2] for k, v in pos.items()}

    labels = nx.get_edge_attributes(G, 'weight')
    nx.draw(G, pos, with_labels=True, node_size=700, node_color='skyblue', font_size=8, font_color='black',
            connectionstyle='arc3,rad=0.1')

    # Annotate edges manually with adjusted positions to avoid overlap
    for edge, weight in labels.items():
        (x, y) = pos[edge[0]]
        text_x = 3/4*x + 1/4*pos[edge[1]][0]
        text_y = 3/4*y + 1/4*pos[edge[1]][1]
        #shift text to avoid overlap
        text_y += 0.2 if edge[0] == edge[1] else 0


        plt.text(text_x, text_y, f"{weight}", fontsize=8, color='blue', verticalalignment='center',
                 horizontalalignment='center')
    plt.title(title)
    plt.show()
    
    
def combine_overlaps(df):
    """
    this functions combines any time overlaps present in the dataframe for each generator
    so that for every time t there is at most one row describing the generator at time t.
    df: dataframe containing UnitName, StartTS, EndTS
    """

    # Step 1: Sort the DataFrame
    df.sort_values(by=["UnitName", "StartTS"], inplace=True)

    # Step 2 and 3: Combine overlapping intervals
    result = []
    current_interval = None
    n_rows = df.shape[0]
    perc = n_rows // 100 *  5

    for k, row in df.iterrows():
        if k % perc == 0:
            print(f"percentage of rows parsed = {k / n_rows *100:.2f}%")
        if current_interval is None:
             current_interval = row.copy()
        elif row["StartTS"] >= current_interval["EndTS"] or row["UnitName"] != current_interval["UnitName"]:
            # No overlap or new UnitID
            result.append(current_interval)
            current_interval = row.copy()
        else:
            # Overlapping intervals, update the EndTS
            current_interval["EndTS"] = row["StartTS"]

    result_df = pd.DataFrame(result)

    return result_df


def get_markov_probs(df, states_column):
    """
    input:
    df: dataframe having as columns: states_column, "ProductionType", "StartTS", "UpTime"
    states_column: string with name of column where the state of the generator is saved
    output: dictionary having as keys tuples with two states and the associated probability transition
    """
    states = list(df[states_column].unique())
    states.append("Running")
    transitions = []
    for x in states:
        for y in states:
            transitions.append((x,y))
            
    transitions_counter = dict(zip(transitions, [0]*len(transitions)))
    GenGroups = df.groupby("UnitName")
    previous_state = "Running"
    current_state = "Running"
    for unit_name, unit_df in GenGroups:
        unit_df = unit_df.sort_values(["StartTS"])
        #count transition occurante for unit
        for index, row in unit_df.iterrows():
            uptime = row["RunningTime"]
            #get current state from row
            current_state = row[states_column]

            if pd.isna(uptime):
                #if uptime == "Nan" then it was the first recorded instance of the generator in the dataframe so before it was running.
                previous_state = "Running"
            elif uptime > 10 / (60 * 24): # and previous_state != "Running"
                #if the generator had some time between the previous row than the previous state was running
                #and we must add 1 to previousprevious state and running
                transitions_counter[(previous_state, "Running")] += 1
                previous_state = "Running"    

            transitions_counter[(previous_state, current_state)] += 1
            #the current state becomes the previous_state
            previous_state = current_state

    #get the transtions probabilities
    transitions_probs = transitions_counter
    counter_dict = dict(zip(states, [0]*len(states)))
    for state in states:
        for transition, counter in transitions_probs.items():
            if transition[0] == state:
                counter_dict[state] += counter 

    for transition, counter in transitions_probs.items():
        if counter_dict[transition[0]] != 0:
            #if transition[0] occurs at least one time
            transitions_probs[transition] = transitions_probs[transition] / counter_dict[transition[0]]
    return transitions_probs

def weighted_values(values, probabilities, size):
    bins = np.add.accumulate(probabilities)
    return values[np.digitize(np.random.random_sample(size), bins)]

def next_state_markov(markov, current_state):
    possible_states = []
    transition_probs = []
    for key, prob in markov.items():
        if key[0] == current_state and prob != 0:
            possible_states.append(key[1])
            transition_probs.append(prob)
    #if len(possible_states) == 0:
    #    return current_state
    #else:
    return weighted_values(np.array(possible_states), np.array(transition_probs),1)[0]

def get_gen_type(geo_df):
    geo_to_entsoe_gen_d = {
        "Hard Coal": "Fossil Hard coal ", 
        'Lignite' : 'Fossil Brown coal/Lignite ',
        'Oil': "Fossil Oil ",
        'Waste': "Waste ",
        'Natural Gas': "Fossil Gas ",#o ci andrebbe qualcos altro
        #'Hydro',
        'Nuclear': "Nuclear ", 
        'Other' : "Other ", 
        'Solar':"Solar ",
        'Wind':"Wind Onshore ",
        'Geothermal':"Geothermal "
        }
    #given a unit row of geo dataframe give gen type in ENTSOE format
    #in geo there is just one windpower type (not onshore or offshore) or maybe you can see from the dataframe
    fuel_type = geo_df["Fueltype"]
    gen_type = geo_df["Technology"]
    if fuel_type == "Hydro":
        if gen_type == "Reservoir":
            return 'Hydro Water Reservoir '
        elif gen_type == "Run-Of-River":
            return 'Hydro Run-of-river and poundage '
        elif gen_type == "Pumped Storage":
            return 'Hydro Pumped Storage '
    elif fuel_type in geo_to_entsoe_gen_d.keys():
        return geo_to_entsoe_gen_d[fuel_type]
    else:
        print(f"Generetor {gen_type},{fuel_type} not found classfied as Other")
        return "Other "
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %% [markdown]
# # Questions:
# 1. There is no onshore / offshore windpower ---> remove them
# 2. What is Hydro without further specification
# 3. For what timeframe should I generate data?
# 4. Solar ----> remove them
#
# # TODO:
# - ~remove redundant gens in geo~
# - ~add seed for random variables~

# %%
#Set parameters
geo = pm.data.GEO()
geo = geo.groupby("projectID").head(1)

start_time = np.datetime64("2023-01-01T00:00:00")
end_time = np.datetime64("2023-06-01T00:00:00")
seed = 2193 #set for replicable scenario generation
#import distribution parameters

# %% [markdown]
# ## Dataset descripiton
#
#     - projectID - Immutable identifier of the power plant
#
#     - Power plant name - claim of each database
#
#     - Fueltype - {Bioenergy, Geothermal, Hard Coal, Hydro, Lignite, Nuclear, Natural Gas, Oil, Solar, Wind, Other}
#
#     - Technology - {CCGT, OCGT, Steam Turbine, Combustion Engine, Run-Of-River, Pumped Storage, Reservoir}
#
#     - Set - {Power Plant (PP), Combined Heat and Power (CHP), Storages (Stores)}
#
#     - Capacity - [MW]
#
#     - Duration - Maximum state of charge capacity in terms of hours at full output capacity
#
#     - Dam Information - Dam volume [Mm^3] and Dam Height [m]
#
#     - Geo-position - Latitude, Longitude
#
#     - Country - EU-27 + CH + NO (+ UK) minus Cyprus and Malta
#
#     - YearCommissioned - Commmisioning year of the powerplant
#
#     - RetroFit - Year of last retrofit

# %%
#Import Outages Dataframe to construct model ENTSO-E format
data_path = "../outagesmodelingdata/"
df = pd.read_csv(data_path+"deltaWithEverything_df.csv", parse_dates = [0,1])
df["StartTS"] = pd.to_datetime(df["StartTS"])
df["EndTS"] = pd.to_datetime(df["EndTS"])
df = df.sort_values(["UnitName","StartTS"])

#Combine overlaps fo that every generator is only at one state at the time
df = combine_overlaps(df)
#combine countries
df["MapCode"] = df["MapCode"].apply(lambda x: x[0:2])
# Out:
# percentage of rows parsed = 0.00%
# percentage of rows parsed = 5.00%
# percentage of rows parsed = 10.00%
# percentage of rows parsed = 15.00%
# percentage of rows parsed = 20.00%
# percentage of rows parsed = 25.00%
# percentage of rows parsed = 30.00%
# percentage of rows parsed = 35.00%
# percentage of rows parsed = 39.99%
# percentage of rows parsed = 44.99%
# percentage of rows parsed = 49.99%
# percentage of rows parsed = 54.99%
# percentage of rows parsed = 59.99%
# percentage of rows parsed = 64.99%
# percentage of rows parsed = 69.99%
# percentage of rows parsed = 74.99%
# percentage of rows parsed = 79.99%
# percentage of rows parsed = 84.99%
# percentage of rows parsed = 89.99%
# percentage of rows parsed = 94.99%
# percentage of rows parsed = 99.99%

# %%
#Create model
#statetime_df: dataframe with the parametres of the exponantialdistribution of statetime
#markov_d: dictionary of markov chains of the various generator types
#capacity_d: dictionary of distributions of capacity in p.u.
#STATE TIME MODELING

#In this section we model the time a generator spends in a certain state. We model the random variable time in each state with a exponential distribution using the maximum likelyhood estimator (MLE).

#Change state_column to look ad different state distributions
state_column = "Type"

#def state_time_distribution_fitting(df, state_column):

states = list(df[state_column].unique())
delta_df = df
delta_df = delta_df.sort_values(by = ["UnitName", "StartTS"])

for state in states:
    #calculate time spend in each state
    delta_df[state+"Time"] = [np.datetime64("NaT")]*df.shape[0]
    state_df = delta_df[delta_df[state_column] == state]
    delta_df.loc[delta_df[state_column] == state, state+"Time"] = state_df["EndTS"] - state_df["StartTS"]
    delta_df[state+"Time"] = (delta_df[state+"Time"] /  np.timedelta64(1, 'h'))
    
for unit, unit_df in delta_df.groupby("UnitName"):                             
    unit_df["EndTS"] = pd.to_datetime(unit_df["EndTS"])
    shifted_endts = pd.to_datetime(unit_df["EndTS"].shift())
    start_ts = delta_df.loc[delta_df["UnitName"] == unit, "StartTS"]
    delta_df.loc[delta_df["UnitName"] == unit, "RunningTime"] = start_ts - shifted_endts

delta_df["RunningTime"] = (delta_df["RunningTime"] /  np.timedelta64(1, 'h'))
delta_df.loc[delta_df["RunningTime"] == 0, "RunningTime"] = np.nan

states = states + ["Running"]


#fit outages distributions
statetime_df = pd.DataFrame() #create empty parameter table
grouped_delta = delta_df.groupby(["ProductionType"])
statetime_df["ProductionType"] = grouped_delta.first().reset_index()["ProductionType"]
for state in states:
    statetime_df[state + "Time"] = [np.nan]*len(list(statetime_df["ProductionType"]))


def exponential_fit(x, scale):
    return expon.pdf(x, scale=scale)


for group_name, group_df in grouped_delta:
    
    #We drop NaN valued rows
    #group_df = group_df.dropna(subset = ["UpTime","OffTime"])
    
    for state in states:
        if not pd.isna(group_df[state+"Time"].mean()):
            # Fit the data to the exponential function
            mean = group_df[state+"Time"].mean()
            state_scale = mean
            statetime_df.loc[statetime_df["ProductionType"] == group_name[0], state+"Time"] = state_scale
            #plt.figure() #uncomment to plot
            #plt.xlim(0, 3*mean)  # Adjust the values as needed
            #plt.ylim(0, 1)  # Adjust the values as needed
            #plt.hist(group_df[state + "Time"], bins=5000, edgecolor='black', density=True)
            # Plot the fitted exponential distribution
            #x = np.sort(group_df[state + "Time"])
            #plt.plot(x, exponential_fit(x, scale = state_scale), 'r-', label='Exponential Fit')
            #plt.xlabel(f'Duration {state + "Time"}')
            #plt.ylabel('Frequency')
            #plt.title(f'{state}Time {group_name}')
            #plt.legend()
            #plt.show()


            
#MARKOV CHAIN MODELING
print("Starting Markov chain modeling")
df = delta_df[delta_df["Reason"] != "Shutdown" ] #remove shutdowns 

markov_d= {}
#Create a list containing tuples rapresenting all possible state changes (x,y) := x --> y
#data is a dataframe containing the correct "UpTime" between the states considered

GenTypeGroup_df = df.groupby("ProductionType")

#We can use different states
#print markov chain for each type of generator
for production_type, data in GenTypeGroup_df:
    transitions_probs = get_markov_probs(data, "Type")
    markov_d[production_type] = transitions_probs
    #uncomment to plot:
    #markov_graph(transitions_probs, title = f"{production_type} Markov Chain")

#t_probs = dict(transitions_probs)
#for key, value in transitions_probs.items():
#    if value < 0.05:
#        del t_probs[key]
#print graph


#CAPACITY MODELING
print("Starting Capacity Modeling")
#With Kernel density estimation
grouped_df = df.groupby(["ProductionType", "Type"])
capacity_d = {}
#idea: calculate prob for capacity = 0, remove and the use non parametric fit.
for production_type, prod_df in grouped_df:
    #calculate per unit available capacity
    PU = prod_df["AvailableCapacity"].copy() / prod_df["InstalledCapacity"]
    df.loc[(df["ProductionType"] == production_type[0]) & (df["Type"] == production_type[1]), "p.u."] = PU
    PU = PU[~np.isnan(PU)]
    p_0 = np.sum(PU == 0) / len(PU)
    PUplus = np.sort(PU[PU != 0]) #non zero capacities
    if len(PUplus) != 0:
        
        colors = ["r"]
        kernels = ["gaussian"]
        lw = 2
        #Uncomment to plot
        
        #plt.figure()
        for color, kernel in zip(colors, kernels):
            kde = KernelDensity(kernel=kernel, bandwidth=0.05).fit(PUplus[:, np.newaxis])
            capacity_d[production_type] = (p_0, kde)
            log_dens = kde.score_samples(PUplus[:, np.newaxis]) * len(PUplus) / len(PU) #scale to be prob on non zero values
            Y = np.exp(log_dens)
            #plt.plot(PUplus, Y, color = color, label = kernel)
            
        """
        # Plot histogram

        plt.xlim(0, 1)
        
        plt.hist(PU, bins=min(500, int(np.ceil(len(PU) ** (1. / 3))*3/2)) + 3 , edgecolor='black', alpha=0.7, density = True)

        # Customize the plot (add labels, title, etc.)
        plt.xlabel('p.u. Available Capacity')
        plt.ylabel('Frequency')
        plt.title(f'{production_type}')
        plt.legend()
        plt.show()
        """
# Out:
# Starting Markov chain modeling
# Starting Capacity Modeling
# /tmp/ipykernel_8777/416507078.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[(df["ProductionType"] == production_type[0]) & (df["Type"] == production_type[1]), "p.u."] = PU

# %%
geo_gen_types = geo["Technology"].unique()
geo_fuel_types = geo["Fueltype"].unique()
grouped  = df.groupby(["UnitName"]).first().reset_index()
entsoe_gen_types = list(grouped["ProductionType"].unique())

# %%
# Generating Scenarios

#Starting state --> we roll random running time for every generator the end
# todo: make the markov chaing run for a while to make the various generators get further in states
#np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)
np.random.seed(seed)
grouped  = df.groupby(["UnitName"]).first().reset_index()
gen_names = list(geo["projectID"])
gen_types = []
for index, geo_row in geo.iterrows():
    gen_type = get_gen_type(geo_row)
    if gen_type is None:
        tech = geo_row["Technology"]
        fuel = geo_row["Fueltype"]
        print("Weird thing:", tech, fuel)
        gen_types.append("Other ")
    else:
        gen_types.append(gen_type)

n_gens = len(gen_names)
pre_run_hours = 6*30*24 #time the chain is run for before producing data

states = ["Running", "Forced", "Planned"]
state_df = pd.DataFrame({"UnitName": gen_names, "ProductionType": gen_types, "State":["Running"]*n_gens, "Counter":[0]*n_gens, "Capacity":[1]*n_gens})
perc = np.ceil(pre_run_hours / 100)

for h in np.arange(pre_run_hours):
    
    if h % (perc) == 0:
        print(f"{h/pre_run_hours *100} %")
        print(state_df.head(5))
    
    for index, gen_row in state_df[state_df["Counter"] == 0].iterrows():
        gen_name = gen_row["UnitName"] #remove?
        gen_type = gen_row["ProductionType"]
        current_state = gen_row["State"]
        markov = markov_d[gen_type] #get associate markov chain
        
        new_state = next_state_markov(markov, current_state) #get new state of the generator
        
        scale = statetime_df.loc[statetime_df["ProductionType"] == gen_type, new_state + "Time"]
        new_counter = np.ceil(np.random.exponential(scale, 1))[0] #get number of hours spent in new_state
        
        #get the capacity of the generator in the currnent state
        if new_state == "Running":
            new_capacity = 1
        elif (gen_type, new_state) in capacity_d.keys():
            p_zero, pu_pdf = capacity_d[(gen_type, new_state)]
            if np.random.random_sample(1)[0] <= p_zero:
                new_capacity = 0
            else:
                new_capacity = pu_pdf.sample(1)[0][0]
                if new_capacity < 0:
                    new_capacity = 0
                elif new_capacity > 1:
                    new_capacity = 1
        else:
            #todo this should not happen
            #print(f"no capacity distribution for {gen_type}")
            new_capacity = 1
        
        state_df.loc[index, ["State", "Counter", "Capacity"]] = [new_state, new_counter, new_capacity]
        
    state_df.loc[state_df["Counter"] != 0, "Counter"] -= 1
    
#idea: 
# while t < 10 years roll dices take final state and final counter
# Out:
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# Weird thing: nan Hydro
# 0.0 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running        0         1
# 1  GEO-45150  Fossil Hard coal   Running        0         1
# 2  GEO-45719  Fossil Hard coal   Running        0         1
# 3  GEO-41956  Fossil Hard coal   Running        0         1
# 4  GEO-41974  Fossil Hard coal   Running        0         1
# 1.0185185185185186 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Planned        6       0.0
# 1  GEO-45150  Fossil Hard coal   Planned       14       0.0
# 2  GEO-45719  Fossil Hard coal   Running      146       1.0
# 3  GEO-41956  Fossil Hard coal   Planned       13       0.0
# 4  GEO-41974  Fossil Hard coal   Planned       12       0.0
# 2.037037037037037 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       65  1.000000
# 1  GEO-45150  Fossil Hard coal    Forced       53  0.899174
# 2  GEO-45719  Fossil Hard coal   Running      102  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      847  1.000000
# 4  GEO-41974  Fossil Hard coal   Running       17  1.000000
# 3.0555555555555554 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       21  1.000000
# 1  GEO-45150  Fossil Hard coal    Forced        9  0.899174
# 2  GEO-45719  Fossil Hard coal   Running       58  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      803  1.000000
# 4  GEO-41974  Fossil Hard coal   Running      174  1.000000
# 4.074074074074074 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal    Forced       41  0.478246
# 1  GEO-45150  Fossil Hard coal   Running      276  1.000000
# 2  GEO-45719  Fossil Hard coal   Running       14  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      759  1.000000
# 4  GEO-41974  Fossil Hard coal   Running      130  1.000000
# 5.092592592592593 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      616  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      232  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       83  0.856107
# 3  GEO-41956  Fossil Hard coal   Running      715  1.000000
# 4  GEO-41974  Fossil Hard coal   Running       86  1.000000
# 6.111111111111111 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      572  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      188  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       39  0.856107
# 3  GEO-41956  Fossil Hard coal   Running      671  1.000000
# 4  GEO-41974  Fossil Hard coal   Running       42  1.000000
# 7.12962962962963 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      528  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      144  1.000000
# 2  GEO-45719  Fossil Hard coal   Running      169  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      627  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned       36  0.867568
# 8.148148148148149 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      484       1.0
# 1  GEO-45150  Fossil Hard coal   Running      100       1.0
# 2  GEO-45719  Fossil Hard coal   Running      125       1.0
# 3  GEO-41956  Fossil Hard coal   Running      583       1.0
# 4  GEO-41974  Fossil Hard coal   Running      148       1.0
# 9.166666666666666 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      440       1.0
# 1  GEO-45150  Fossil Hard coal   Running       56       1.0
# 2  GEO-45719  Fossil Hard coal   Running       81       1.0
# 3  GEO-41956  Fossil Hard coal   Running      539       1.0
# 4  GEO-41974  Fossil Hard coal   Running      104       1.0
# 10.185185185185185 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      396       1.0
# 1  GEO-45150  Fossil Hard coal   Running       12       1.0
# 2  GEO-45719  Fossil Hard coal   Running       37       1.0
# 3  GEO-41956  Fossil Hard coal   Running      495       1.0
# 4  GEO-41974  Fossil Hard coal   Running       60       1.0
# 11.203703703703702 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      352       1.0
# 1  GEO-45150  Fossil Hard coal    Forced       14       0.0
# 2  GEO-45719  Fossil Hard coal   Planned       17       0.0
# 3  GEO-41956  Fossil Hard coal   Running      451       1.0
# 4  GEO-41974  Fossil Hard coal   Running       16       1.0
# 12.222222222222221 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      308  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      410  1.000000
# 2  GEO-45719  Fossil Hard coal   Running       41  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      407  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned      186  0.316902
# 13.240740740740742 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      264  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      366  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       79  0.000000
# 3  GEO-41956  Fossil Hard coal   Running      363  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned      142  0.316902
# 14.25925925925926 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      220  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      322  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       35  0.000000
# 3  GEO-41956  Fossil Hard coal   Running      319  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned       98  0.316902
# 15.277777777777779 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      176  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      278  1.000000
# 2  GEO-45719  Fossil Hard coal   Running       31  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      275  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned       54  0.316902
# 16.296296296296298 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      132  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      234  1.000000
# 2  GEO-45719  Fossil Hard coal   Running      109  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      231  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned       10  0.316902
# 17.314814814814813 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       88       1.0
# 1  GEO-45150  Fossil Hard coal   Running      190       1.0
# 2  GEO-45719  Fossil Hard coal   Running       65       1.0
# 3  GEO-41956  Fossil Hard coal   Running      187       1.0
# 4  GEO-41974  Fossil Hard coal   Running      103       1.0
# 18.333333333333332 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       44       1.0
# 1  GEO-45150  Fossil Hard coal   Running      146       1.0
# 2  GEO-45719  Fossil Hard coal   Running       21       1.0
# 3  GEO-41956  Fossil Hard coal   Running      143       1.0
# 4  GEO-41974  Fossil Hard coal   Running       59       1.0
# 19.35185185185185 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running        0       1.0
# 1  GEO-45150  Fossil Hard coal   Running      102       1.0
# 2  GEO-45719  Fossil Hard coal   Planned       73       0.0
# 3  GEO-41956  Fossil Hard coal   Running       99       1.0
# 4  GEO-41974  Fossil Hard coal   Running       15       1.0
# 20.37037037037037 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Planned       51  0.878238
# 1  GEO-45150  Fossil Hard coal   Running       58  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       29  0.000000
# 3  GEO-41956  Fossil Hard coal   Running       55  1.000000
# 4  GEO-41974  Fossil Hard coal   Running       50  1.000000
# 21.38888888888889 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Planned        7  0.878238
# 1  GEO-45150  Fossil Hard coal   Running       14  1.000000
# 2  GEO-45719  Fossil Hard coal   Running      100  1.000000
# 3  GEO-41956  Fossil Hard coal   Running       11  1.000000
# 4  GEO-41974  Fossil Hard coal   Running        6  1.000000
# 22.407407407407405 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      396       1.0
# 1  GEO-45150  Fossil Hard coal   Planned       61       0.0
# 2  GEO-45719  Fossil Hard coal   Running       56       1.0
# 3  GEO-41956  Fossil Hard coal   Running       71       1.0
# 4  GEO-41974  Fossil Hard coal   Running      114       1.0
# 23.425925925925924 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      352       1.0
# 1  GEO-45150  Fossil Hard coal   Planned       17       0.0
# 2  GEO-45719  Fossil Hard coal   Running       12       1.0
# 3  GEO-41956  Fossil Hard coal   Running       27       1.0
# 4  GEO-41974  Fossil Hard coal   Running       70       1.0
# 24.444444444444443 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      308  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      588  1.000000
# 2  GEO-45719  Fossil Hard coal   Running      155  1.000000
# 3  GEO-41956  Fossil Hard coal    Forced       36  0.926455
# 4  GEO-41974  Fossil Hard coal   Running       26  1.000000
# 25.462962962962965 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      264  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      544  1.000000
# 2  GEO-45719  Fossil Hard coal   Running      111  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      405  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned       21  0.498649
# 26.481481481481485 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      220       1.0
# 1  GEO-45150  Fossil Hard coal   Running      500       1.0
# 2  GEO-45719  Fossil Hard coal   Running       67       1.0
# 3  GEO-41956  Fossil Hard coal   Running      361       1.0
# 4  GEO-41974  Fossil Hard coal   Running      187       1.0
# 27.500000000000004 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      176       1.0
# 1  GEO-45150  Fossil Hard coal   Running      456       1.0
# 2  GEO-45719  Fossil Hard coal   Running       23       1.0
# 3  GEO-41956  Fossil Hard coal   Running      317       1.0
# 4  GEO-41974  Fossil Hard coal   Running      143       1.0
# 28.51851851851852 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      132       1.0
# 1  GEO-45150  Fossil Hard coal   Running      412       1.0
# 2  GEO-45719  Fossil Hard coal   Planned       18       0.0
# 3  GEO-41956  Fossil Hard coal   Running      273       1.0
# 4  GEO-41974  Fossil Hard coal   Running       99       1.0
# 29.537037037037038 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       88       1.0
# 1  GEO-45150  Fossil Hard coal   Running      368       1.0
# 2  GEO-45719  Fossil Hard coal   Running       19       1.0
# 3  GEO-41956  Fossil Hard coal   Running      229       1.0
# 4  GEO-41974  Fossil Hard coal   Running       55       1.0
# 30.555555555555557 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       44       1.0
# 1  GEO-45150  Fossil Hard coal   Running      324       1.0
# 2  GEO-45719  Fossil Hard coal   Running      319       1.0
# 3  GEO-41956  Fossil Hard coal   Running      185       1.0
# 4  GEO-41974  Fossil Hard coal   Running       11       1.0
# 31.574074074074076 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running        0       1.0
# 1  GEO-45150  Fossil Hard coal   Running      280       1.0
# 2  GEO-45719  Fossil Hard coal   Running      275       1.0
# 3  GEO-41956  Fossil Hard coal   Running      141       1.0
# 4  GEO-41974  Fossil Hard coal   Running       63       1.0
# 32.592592592592595 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      492       1.0
# 1  GEO-45150  Fossil Hard coal   Running      236       1.0
# 2  GEO-45719  Fossil Hard coal   Running      231       1.0
# 3  GEO-41956  Fossil Hard coal   Running       97       1.0
# 4  GEO-41974  Fossil Hard coal   Running       19       1.0
# 33.611111111111114 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      448  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      192  1.000000
# 2  GEO-45719  Fossil Hard coal   Running      187  1.000000
# 3  GEO-41956  Fossil Hard coal   Running       53  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned       15  0.555277
# 34.629629629629626 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      404       1.0
# 1  GEO-45150  Fossil Hard coal   Running      148       1.0
# 2  GEO-45719  Fossil Hard coal   Running      143       1.0
# 3  GEO-41956  Fossil Hard coal   Running        9       1.0
# 4  GEO-41974  Fossil Hard coal   Running      251       1.0
# 35.648148148148145 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      360  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      104  1.000000
# 2  GEO-45719  Fossil Hard coal   Running       99  1.000000
# 3  GEO-41956  Fossil Hard coal   Planned      137  0.968042
# 4  GEO-41974  Fossil Hard coal   Running      207  1.000000
# 36.666666666666664 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      316  1.000000
# 1  GEO-45150  Fossil Hard coal   Running       60  1.000000
# 2  GEO-45719  Fossil Hard coal   Running       55  1.000000
# 3  GEO-41956  Fossil Hard coal   Planned       93  0.968042
# 4  GEO-41974  Fossil Hard coal   Running      163  1.000000
# 37.68518518518518 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      272  1.000000
# 1  GEO-45150  Fossil Hard coal   Running       16  1.000000
# 2  GEO-45719  Fossil Hard coal   Running       11  1.000000
# 3  GEO-41956  Fossil Hard coal   Planned       49  0.968042
# 4  GEO-41974  Fossil Hard coal   Running      119  1.000000
# 38.7037037037037 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      228  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      123  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       23  0.749148
# 3  GEO-41956  Fossil Hard coal   Planned        5  0.968042
# 4  GEO-41974  Fossil Hard coal   Running       75  1.000000
# 39.72222222222222 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      184       1.0
# 1  GEO-45150  Fossil Hard coal   Running       79       1.0
# 2  GEO-45719  Fossil Hard coal   Running      409       1.0
# 3  GEO-41956  Fossil Hard coal   Running      105       1.0
# 4  GEO-41974  Fossil Hard coal   Running       31       1.0
# 40.74074074074074 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      140       1.0
# 1  GEO-45150  Fossil Hard coal   Running       35       1.0
# 2  GEO-45719  Fossil Hard coal   Running      365       1.0
# 3  GEO-41956  Fossil Hard coal   Running       61       1.0
# 4  GEO-41974  Fossil Hard coal   Planned      107       0.0
# 41.75925925925926 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       96  1.000000
# 1  GEO-45150  Fossil Hard coal   Planned       94  0.585135
# 2  GEO-45719  Fossil Hard coal   Running      321  1.000000
# 3  GEO-41956  Fossil Hard coal   Running       17  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned       63  0.000000
# 42.77777777777778 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       52  1.000000
# 1  GEO-45150  Fossil Hard coal   Planned       50  0.585135
# 2  GEO-45719  Fossil Hard coal   Running      277  1.000000
# 3  GEO-41956  Fossil Hard coal   Running       15  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned       19  0.000000
# 43.7962962962963 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running        8  1.000000
# 1  GEO-45150  Fossil Hard coal   Planned        6  0.585135
# 2  GEO-45719  Fossil Hard coal   Running      233  1.000000
# 3  GEO-41956  Fossil Hard coal   Planned        6  0.604555
# 4  GEO-41974  Fossil Hard coal   Running      437  1.000000
# 44.81481481481481 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       28       1.0
# 1  GEO-45150  Fossil Hard coal   Running      130       1.0
# 2  GEO-45719  Fossil Hard coal   Running      189       1.0
# 3  GEO-41956  Fossil Hard coal   Running       48       1.0
# 4  GEO-41974  Fossil Hard coal   Running      393       1.0
# 45.83333333333333 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      263       1.0
# 1  GEO-45150  Fossil Hard coal   Running       86       1.0
# 2  GEO-45719  Fossil Hard coal   Running      145       1.0
# 3  GEO-41956  Fossil Hard coal   Running        4       1.0
# 4  GEO-41974  Fossil Hard coal   Running      349       1.0
# 46.85185185185185 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      219       1.0
# 1  GEO-45150  Fossil Hard coal   Running       42       1.0
# 2  GEO-45719  Fossil Hard coal   Running      101       1.0
# 3  GEO-41956  Fossil Hard coal   Planned        2       0.0
# 4  GEO-41974  Fossil Hard coal   Running      305       1.0
# 47.87037037037037 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      175       1.0
# 1  GEO-45150  Fossil Hard coal   Planned       20       1.0
# 2  GEO-45719  Fossil Hard coal   Running       57       1.0
# 3  GEO-41956  Fossil Hard coal   Running      164       1.0
# 4  GEO-41974  Fossil Hard coal   Running      261       1.0
# 48.888888888888886 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      131       1.0
# 1  GEO-45150  Fossil Hard coal   Running       98       1.0
# 2  GEO-45719  Fossil Hard coal   Running       13       1.0
# 3  GEO-41956  Fossil Hard coal   Running      120       1.0
# 4  GEO-41974  Fossil Hard coal   Running      217       1.0
# 49.907407407407405 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       87       1.0
# 1  GEO-45150  Fossil Hard coal   Running       54       1.0
# 2  GEO-45719  Fossil Hard coal   Running      214       1.0
# 3  GEO-41956  Fossil Hard coal   Running       76       1.0
# 4  GEO-41974  Fossil Hard coal   Running      173       1.0
# 50.92592592592593 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       43       1.0
# 1  GEO-45150  Fossil Hard coal   Running       10       1.0
# 2  GEO-45719  Fossil Hard coal   Running      170       1.0
# 3  GEO-41956  Fossil Hard coal   Running       32       1.0
# 4  GEO-41974  Fossil Hard coal   Running      129       1.0
# 51.94444444444445 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Planned        9  0.775704
# 1  GEO-45150  Fossil Hard coal   Planned       62  0.533100
# 2  GEO-45719  Fossil Hard coal   Running      126  1.000000
# 3  GEO-41956  Fossil Hard coal    Forced      180  0.854222
# 4  GEO-41974  Fossil Hard coal   Running       85  1.000000
# 52.96296296296297 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      135  1.000000
# 1  GEO-45150  Fossil Hard coal   Planned       18  0.533100
# 2  GEO-45719  Fossil Hard coal   Running       82  1.000000
# 3  GEO-41956  Fossil Hard coal    Forced      136  0.854222
# 4  GEO-41974  Fossil Hard coal   Running       41  1.000000
# 53.98148148148149 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       91  1.000000
# 1  GEO-45150  Fossil Hard coal   Running       25  1.000000
# 2  GEO-45719  Fossil Hard coal   Running       38  1.000000
# 3  GEO-41956  Fossil Hard coal    Forced       92  0.854222
# 4  GEO-41974  Fossil Hard coal   Planned       27  0.000000
# 55.00000000000001 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       47  1.000000
# 1  GEO-45150  Fossil Hard coal   Planned       72  0.891057
# 2  GEO-45719  Fossil Hard coal   Planned      123  0.506000
# 3  GEO-41956  Fossil Hard coal    Forced       48  0.854222
# 4  GEO-41974  Fossil Hard coal   Running       66  1.000000
# 56.018518518518526 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running        3  1.000000
# 1  GEO-45150  Fossil Hard coal   Planned       28  0.891057
# 2  GEO-45719  Fossil Hard coal   Planned       79  0.506000
# 3  GEO-41956  Fossil Hard coal    Forced        4  0.854222
# 4  GEO-41974  Fossil Hard coal   Running       22  1.000000
# 57.03703703703704 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal    Forced       30  0.500471
# 1  GEO-45150  Fossil Hard coal   Running      557  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       35  0.506000
# 3  GEO-41956  Fossil Hard coal   Planned        6  0.000000
# 4  GEO-41974  Fossil Hard coal   Running      472  1.000000
# 58.05555555555556 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      712       1.0
# 1  GEO-45150  Fossil Hard coal   Running      513       1.0
# 2  GEO-45719  Fossil Hard coal   Running      360       1.0
# 3  GEO-41956  Fossil Hard coal   Running      222       1.0
# 4  GEO-41974  Fossil Hard coal   Running      428       1.0
# 59.074074074074076 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      668       1.0
# 1  GEO-45150  Fossil Hard coal   Running      469       1.0
# 2  GEO-45719  Fossil Hard coal   Running      316       1.0
# 3  GEO-41956  Fossil Hard coal   Running      178       1.0
# 4  GEO-41974  Fossil Hard coal   Running      384       1.0
# 60.092592592592595 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      624       1.0
# 1  GEO-45150  Fossil Hard coal   Running      425       1.0
# 2  GEO-45719  Fossil Hard coal   Running      272       1.0
# 3  GEO-41956  Fossil Hard coal   Running      134       1.0
# 4  GEO-41974  Fossil Hard coal   Running      340       1.0
# 61.111111111111114 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      580       1.0
# 1  GEO-45150  Fossil Hard coal   Running      381       1.0
# 2  GEO-45719  Fossil Hard coal   Running      228       1.0
# 3  GEO-41956  Fossil Hard coal   Running       90       1.0
# 4  GEO-41974  Fossil Hard coal   Running      296       1.0
# 62.12962962962963 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      536       1.0
# 1  GEO-45150  Fossil Hard coal   Running      337       1.0
# 2  GEO-45719  Fossil Hard coal   Running      184       1.0
# 3  GEO-41956  Fossil Hard coal   Running       46       1.0
# 4  GEO-41974  Fossil Hard coal   Running      252       1.0
# 63.14814814814815 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      492       1.0
# 1  GEO-45150  Fossil Hard coal   Running      293       1.0
# 2  GEO-45719  Fossil Hard coal   Running      140       1.0
# 3  GEO-41956  Fossil Hard coal   Running        2       1.0
# 4  GEO-41974  Fossil Hard coal   Running      208       1.0
# 64.16666666666667 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      448       1.0
# 1  GEO-45150  Fossil Hard coal   Running      249       1.0
# 2  GEO-45719  Fossil Hard coal   Running       96       1.0
# 3  GEO-41956  Fossil Hard coal   Running      119       1.0
# 4  GEO-41974  Fossil Hard coal   Running      164       1.0
# 65.18518518518519 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      404       1.0
# 1  GEO-45150  Fossil Hard coal   Running      205       1.0
# 2  GEO-45719  Fossil Hard coal   Running       52       1.0
# 3  GEO-41956  Fossil Hard coal   Running       75       1.0
# 4  GEO-41974  Fossil Hard coal   Running      120       1.0
# 66.20370370370371 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      360       1.0
# 1  GEO-45150  Fossil Hard coal   Running      161       1.0
# 2  GEO-45719  Fossil Hard coal   Running        8       1.0
# 3  GEO-41956  Fossil Hard coal   Running       31       1.0
# 4  GEO-41974  Fossil Hard coal   Running       76       1.0
# 67.22222222222223 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      316  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      117  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned      132  0.310827
# 3  GEO-41956  Fossil Hard coal   Running      542  1.000000
# 4  GEO-41974  Fossil Hard coal   Running       32  1.000000
# 68.24074074074075 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      272  1.000000
# 1  GEO-45150  Fossil Hard coal   Running       73  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       88  0.310827
# 3  GEO-41956  Fossil Hard coal   Running      498  1.000000
# 4  GEO-41974  Fossil Hard coal    Forced       95  0.858931
# 69.25925925925925 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      228  1.000000
# 1  GEO-45150  Fossil Hard coal   Running       29  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       44  0.310827
# 3  GEO-41956  Fossil Hard coal   Running      454  1.000000
# 4  GEO-41974  Fossil Hard coal    Forced       51  0.858931
# 70.27777777777777 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      184  1.000000
# 1  GEO-45150  Fossil Hard coal    Forced        5  0.732675
# 2  GEO-45719  Fossil Hard coal   Planned        0  0.310827
# 3  GEO-41956  Fossil Hard coal   Running      410  1.000000
# 4  GEO-41974  Fossil Hard coal    Forced        7  0.858931
# 71.29629629629629 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      140       1.0
# 1  GEO-45150  Fossil Hard coal   Running      100       1.0
# 2  GEO-45719  Fossil Hard coal   Running      423       1.0
# 3  GEO-41956  Fossil Hard coal   Running      366       1.0
# 4  GEO-41974  Fossil Hard coal   Running       18       1.0
# 72.31481481481481 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       96    1.0000
# 1  GEO-45150  Fossil Hard coal   Running       56    1.0000
# 2  GEO-45719  Fossil Hard coal   Running      379    1.0000
# 3  GEO-41956  Fossil Hard coal   Running      322    1.0000
# 4  GEO-41974  Fossil Hard coal   Planned       24    0.0648
# 73.33333333333333 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       52       1.0
# 1  GEO-45150  Fossil Hard coal   Running       12       1.0
# 2  GEO-45719  Fossil Hard coal   Running      335       1.0
# 3  GEO-41956  Fossil Hard coal   Running      278       1.0
# 4  GEO-41974  Fossil Hard coal   Running      349       1.0
# 74.35185185185185 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running        8  1.000000
# 1  GEO-45150  Fossil Hard coal    Forced        2  0.708242
# 2  GEO-45719  Fossil Hard coal   Running      291  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      234  1.000000
# 4  GEO-41974  Fossil Hard coal   Running      305  1.000000
# 75.37037037037037 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       18       1.0
# 1  GEO-45150  Fossil Hard coal   Running      709       1.0
# 2  GEO-45719  Fossil Hard coal   Running      247       1.0
# 3  GEO-41956  Fossil Hard coal   Running      190       1.0
# 4  GEO-41974  Fossil Hard coal   Running      261       1.0
# 76.38888888888889 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Planned       27  0.801221
# 1  GEO-45150  Fossil Hard coal   Running      665  1.000000
# 2  GEO-45719  Fossil Hard coal   Running      203  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      146  1.000000
# 4  GEO-41974  Fossil Hard coal   Running      217  1.000000
# 77.4074074074074 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      115       1.0
# 1  GEO-45150  Fossil Hard coal   Running      621       1.0
# 2  GEO-45719  Fossil Hard coal   Running      159       1.0
# 3  GEO-41956  Fossil Hard coal   Running      102       1.0
# 4  GEO-41974  Fossil Hard coal   Running      173       1.0
# 78.42592592592592 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       71       1.0
# 1  GEO-45150  Fossil Hard coal   Running      577       1.0
# 2  GEO-45719  Fossil Hard coal   Running      115       1.0
# 3  GEO-41956  Fossil Hard coal   Running       58       1.0
# 4  GEO-41974  Fossil Hard coal   Running      129       1.0
# 79.44444444444444 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       27       1.0
# 1  GEO-45150  Fossil Hard coal   Running      533       1.0
# 2  GEO-45719  Fossil Hard coal   Running       71       1.0
# 3  GEO-41956  Fossil Hard coal   Running       14       1.0
# 4  GEO-41974  Fossil Hard coal   Running       85       1.0
# 80.46296296296296 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Planned       25       0.0
# 1  GEO-45150  Fossil Hard coal   Running      489       1.0
# 2  GEO-45719  Fossil Hard coal   Running       27       1.0
# 3  GEO-41956  Fossil Hard coal   Running        9       1.0
# 4  GEO-41974  Fossil Hard coal   Running       41       1.0
# 81.48148148148148 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      133  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      445  1.000000
# 2  GEO-45719  Fossil Hard coal   Running      269  1.000000
# 3  GEO-41956  Fossil Hard coal   Planned       31  0.000000
# 4  GEO-41974  Fossil Hard coal   Planned       11  0.189723
# 82.5 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       89       1.0
# 1  GEO-45150  Fossil Hard coal   Running      401       1.0
# 2  GEO-45719  Fossil Hard coal   Running      225       1.0
# 3  GEO-41956  Fossil Hard coal   Running      271       1.0
# 4  GEO-41974  Fossil Hard coal   Running      738       1.0
# 83.51851851851852 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       45       1.0
# 1  GEO-45150  Fossil Hard coal   Running      357       1.0
# 2  GEO-45719  Fossil Hard coal   Running      181       1.0
# 3  GEO-41956  Fossil Hard coal   Running      227       1.0
# 4  GEO-41974  Fossil Hard coal   Running      694       1.0
# 84.53703703703704 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running        1       1.0
# 1  GEO-45150  Fossil Hard coal   Running      313       1.0
# 2  GEO-45719  Fossil Hard coal   Running      137       1.0
# 3  GEO-41956  Fossil Hard coal   Running      183       1.0
# 4  GEO-41974  Fossil Hard coal   Running      650       1.0
# 85.55555555555556 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       16       1.0
# 1  GEO-45150  Fossil Hard coal   Running      269       1.0
# 2  GEO-45719  Fossil Hard coal   Running       93       1.0
# 3  GEO-41956  Fossil Hard coal   Running      139       1.0
# 4  GEO-41974  Fossil Hard coal   Running      606       1.0
# 86.57407407407408 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Planned       12       0.0
# 1  GEO-45150  Fossil Hard coal   Running      225       1.0
# 2  GEO-45719  Fossil Hard coal   Running       49       1.0
# 3  GEO-41956  Fossil Hard coal   Running       95       1.0
# 4  GEO-41974  Fossil Hard coal   Running      562       1.0
# 87.5925925925926 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running     1094       1.0
# 1  GEO-45150  Fossil Hard coal   Running      181       1.0
# 2  GEO-45719  Fossil Hard coal   Running        5       1.0
# 3  GEO-41956  Fossil Hard coal   Running       51       1.0
# 4  GEO-41974  Fossil Hard coal   Running      518       1.0
# 88.61111111111111 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running     1050       1.0
# 1  GEO-45150  Fossil Hard coal   Running      137       1.0
# 2  GEO-45719  Fossil Hard coal   Planned       74       0.0
# 3  GEO-41956  Fossil Hard coal   Running        7       1.0
# 4  GEO-41974  Fossil Hard coal   Running      474       1.0
# 89.62962962962962 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running     1006  1.000000
# 1  GEO-45150  Fossil Hard coal   Running       93  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       30  0.000000
# 3  GEO-41956  Fossil Hard coal   Planned       46  0.997322
# 4  GEO-41974  Fossil Hard coal   Running      430  1.000000
# 90.64814814814814 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      962  1.000000
# 1  GEO-45150  Fossil Hard coal   Running       49  1.000000
# 2  GEO-45719  Fossil Hard coal   Running       39  1.000000
# 3  GEO-41956  Fossil Hard coal   Planned        2  0.997322
# 4  GEO-41974  Fossil Hard coal   Running      386  1.000000
# 91.66666666666666 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      918  1.000000
# 1  GEO-45150  Fossil Hard coal   Running        5  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned      119  0.563255
# 3  GEO-41956  Fossil Hard coal   Running      389  1.000000
# 4  GEO-41974  Fossil Hard coal   Running      342  1.000000
# 92.68518518518518 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      874  1.000000
# 1  GEO-45150  Fossil Hard coal    Forced       26  0.767103
# 2  GEO-45719  Fossil Hard coal   Planned       75  0.563255
# 3  GEO-41956  Fossil Hard coal   Running      345  1.000000
# 4  GEO-41974  Fossil Hard coal   Running      298  1.000000
# 93.7037037037037 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      830  1.000000
# 1  GEO-45150  Fossil Hard coal   Running       10  1.000000
# 2  GEO-45719  Fossil Hard coal   Planned       31  0.563255
# 3  GEO-41956  Fossil Hard coal   Running      301  1.000000
# 4  GEO-41974  Fossil Hard coal   Running      254  1.000000
# 94.72222222222221 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      786       1.0
# 1  GEO-45150  Fossil Hard coal   Running      104       1.0
# 2  GEO-45719  Fossil Hard coal    Forced       66       0.0
# 3  GEO-41956  Fossil Hard coal   Running      257       1.0
# 4  GEO-41974  Fossil Hard coal   Running      210       1.0
# 95.74074074074073 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      742       1.0
# 1  GEO-45150  Fossil Hard coal   Running       60       1.0
# 2  GEO-45719  Fossil Hard coal    Forced       22       0.0
# 3  GEO-41956  Fossil Hard coal   Running      213       1.0
# 4  GEO-41974  Fossil Hard coal   Running      166       1.0
# 96.75925925925925 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      698       1.0
# 1  GEO-45150  Fossil Hard coal   Running       16       1.0
# 2  GEO-45719  Fossil Hard coal   Running        9       1.0
# 3  GEO-41956  Fossil Hard coal   Running      169       1.0
# 4  GEO-41974  Fossil Hard coal   Running      122       1.0
# 97.77777777777777 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      654  1.000000
# 1  GEO-45150  Fossil Hard coal   Planned        7  0.453466
# 2  GEO-45719  Fossil Hard coal   Running        7  1.000000
# 3  GEO-41956  Fossil Hard coal   Running      125  1.000000
# 4  GEO-41974  Fossil Hard coal   Running       78  1.000000
# 98.79629629629629 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      610  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      279  1.000000
# 2  GEO-45719  Fossil Hard coal    Forced        0  0.638121
# 3  GEO-41956  Fossil Hard coal   Running       81  1.000000
# 4  GEO-41974  Fossil Hard coal   Running       34  1.000000
# 99.81481481481481 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      566  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      235  1.000000
# 2  GEO-45719  Fossil Hard coal   Running      665  1.000000
# 3  GEO-41956  Fossil Hard coal   Running       37  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned       41  0.248235

# %%
# Generating Scenarios
# given a dataframe having UnitName and UnitType create scenarios for each UnitName
# 

np.random.seed(seed)
tot_hours = (end_time - start_time) / np.timedelta64(1, "h")
data_list = []
current_time = start_time
#state_df = pd.DataFrame({"UnitName": gen_names, "ProductionType": gen_types, "State":["Running"]*n_gens, "Counter":[0]*n_gens, "Capacity":[1]*n_gens})

perc = np.ceil(tot_hours / 100)
columns = ["TimeStamp"] + gen_names

for h in np.arange(tot_hours):
    
    if h % (10*perc) == 0:
        print(f"{h/tot_hours *100} %")
        print(state_df.head(5))
    
    for index, gen_row in state_df[state_df["Counter"] == 0].iterrows():
        gen_name = gen_row["UnitName"] #remove?
        gen_type = gen_row["ProductionType"]
        current_state = gen_row["State"]
        markov = markov_d[gen_type] #get associate markov chain
        
        new_state = next_state_markov(markov, current_state) #get new state of the generator
        
        scale = statetime_df.loc[statetime_df["ProductionType"] == gen_type, new_state + "Time"]
        new_counter = np.ceil(np.random.exponential(scale, 1))[0] #get number of hours spent in new_state
        
        #get the capacity of the generator in the currnent state
        if new_state == "Running":
            new_capacity = 1
        elif (gen_type, new_state) in capacity_d.keys():
            p_zero, pu_pdf = capacity_d[(gen_type, new_state)]
            if np.random.random_sample(1)[0] <= p_zero:
                new_capacity = 0
            else:
                new_capacity = pu_pdf.sample(1,random_state = seed)[0][0]
                if new_capacity < 0:
                    new_capacity = 0
                elif new_capacity > 1:
                    new_capacity = 1
        else:
            #todo this should not happen
            #print(f"no capacity distribution for {gen_type}")
            new_capacity = 1
        
        state_df.loc[index, ["State", "Counter", "Capacity"]] = [new_state, new_counter, new_capacity]
        
    state_df.loc[state_df["Counter"] != 0, "Counter"] -= 1
    current_time = current_time + np.timedelta64(1, "h") #move forward one hour
    new_row = [current_time] + list(state_df["Capacity"])
    row_d = dict(zip(columns, new_row))
    data_list.append(row_d)

scenario = pd.DataFrame(data_list)
# Out:
# 0.0 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      558  1.000000
# 1  GEO-45150  Fossil Hard coal   Running      227  1.000000
# 2  GEO-45719  Fossil Hard coal   Running      657  1.000000
# 3  GEO-41956  Fossil Hard coal   Running       29  1.000000
# 4  GEO-41974  Fossil Hard coal   Planned       33  0.248235
# 10.20971302428256 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      188       1.0
# 1  GEO-45150  Fossil Hard coal   Running      331       1.0
# 2  GEO-45719  Fossil Hard coal   Running      287       1.0
# 3  GEO-41956  Fossil Hard coal   Running       55       1.0
# 4  GEO-41974  Fossil Hard coal   Running      237       1.0
# 20.41942604856512 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      281  1.000000
# 1  GEO-45150  Fossil Hard coal    Forced       21  0.948149
# 2  GEO-45719  Fossil Hard coal   Planned       20  1.000000
# 3  GEO-41956  Fossil Hard coal    Forced       27  0.948149
# 4  GEO-41974  Fossil Hard coal   Running      395  1.000000
# 30.629139072847682 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Planned        7       1.0
# 1  GEO-45150  Fossil Hard coal   Running      219       1.0
# 2  GEO-45719  Fossil Hard coal   Running      175       1.0
# 3  GEO-41956  Fossil Hard coal   Planned      111       0.0
# 4  GEO-41974  Fossil Hard coal   Running       25       1.0
# 40.83885209713024 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      152       1.0
# 1  GEO-45150  Fossil Hard coal   Running      221       1.0
# 2  GEO-45719  Fossil Hard coal   Running      286       1.0
# 3  GEO-41956  Fossil Hard coal   Running      227       1.0
# 4  GEO-41974  Fossil Hard coal   Running       89       1.0
# 51.04856512141281 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      377       1.0
# 1  GEO-45150  Fossil Hard coal   Running        5       1.0
# 2  GEO-45719  Fossil Hard coal   Running      240       1.0
# 3  GEO-41956  Fossil Hard coal   Running       67       1.0
# 4  GEO-41974  Fossil Hard coal   Running      115       1.0
# 61.258278145695364 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running        7       1.0
# 1  GEO-45150  Fossil Hard coal   Running      163       1.0
# 2  GEO-45719  Fossil Hard coal   Running        5       1.0
# 3  GEO-41956  Fossil Hard coal   Running      181       1.0
# 4  GEO-41974  Fossil Hard coal   Running       93       1.0
# 71.46799116997794 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Planned        5       0.0
# 1  GEO-45150  Fossil Hard coal   Planned        6       0.0
# 2  GEO-45719  Fossil Hard coal   Running      758       1.0
# 3  GEO-41956  Fossil Hard coal   Planned       11       1.0
# 4  GEO-41974  Fossil Hard coal   Running       71       1.0
# 81.67770419426049 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running       46       1.0
# 1  GEO-45150  Fossil Hard coal   Running      421       1.0
# 2  GEO-45719  Fossil Hard coal   Running      388       1.0
# 3  GEO-41956  Fossil Hard coal   Running      354       1.0
# 4  GEO-41974  Fossil Hard coal   Running       48       1.0
# 91.88741721854305 %
#     UnitName     ProductionType    State  Counter  Capacity
# 0  GEO-45151  Fossil Hard coal   Running      223  1.000000
# 1  GEO-45150  Fossil Hard coal   Running       51  1.000000
# 2  GEO-45719  Fossil Hard coal   Running       18  1.000000
# 3  GEO-41956  Fossil Hard coal    Forced       34  0.948149
# 4  GEO-41974  Fossil Hard coal   Running      661  1.000000

# %%
pd.Series(scenario.columns).map(geo.set_index("projectID").Fueltype)
# Out:
# 0             NaN
# 1       Hard Coal
# 2       Hard Coal
# 3       Hard Coal
# 4       Hard Coal
#           ...
# 1596        Hydro
# 1597        Hydro
# 1598        Hydro
# 1599        Hydro
# 1600        Hydro
# Length: 1601, dtype: object

# %%
scenario.set_index("TimeStamp").groupby(
    [
        pd.Series(scenario.set_index("TimeStamp").columns).map(geo.set_index("projectID").Country).values,
        pd.Series(scenario.set_index("TimeStamp").columns).map(geo.set_index("projectID").Fueltype).values,
    ],
    axis=1
).mean()["Germany"].plot()
# Out:
# <Axes: xlabel='TimeStamp'>

# %%
gen_series = pd.Series(scenario.columns[1:])

scenario.set_index("TimeStamp").groupby(
    [
        gen_series.map(geo.set_index("projectID").Country).values,
        gen_series.map(geo.set_index("projectID").Fueltype).values,
    ],
    axis=1
).mean()["Austria"]
# Out:
#                      Hard Coal     Hydro  Natural Gas   Oil      Wind
# TimeStamp
# 2023-01-01 01:00:00        1.0  0.900049     1.000000  1.00  0.333333
# 2023-01-01 02:00:00        1.0  0.900049     1.000000  1.00  0.333333
# 2023-01-01 03:00:00        1.0  0.900049     1.000000  1.00  0.333333
# 2023-01-01 04:00:00        1.0  0.900049     1.000000  1.00  0.333333
# 2023-01-01 05:00:00        1.0  0.900049     1.000000  1.00  0.333333
# ...                        ...       ...          ...   ...       ...
# 2023-05-31 20:00:00        1.0  0.911357     0.994375  0.75  1.000000
# 2023-05-31 21:00:00        1.0  0.911357     0.994375  0.75  1.000000
# 2023-05-31 22:00:00        1.0  0.911357     0.994375  0.75  1.000000
# 2023-05-31 23:00:00        1.0  0.928599     0.994375  0.75  1.000000
# 2023-06-01 00:00:00        1.0  0.928599     0.994375  0.75  1.000000
#
# [3624 rows x 5 columns]

# %% [markdown]
# # Plot Mean running capacity by type of generator over time

# %%
generators = df.PowerResourceEIC.unique()
start_date = df.StartTS.min() + np.timedelta64(24,"M")
#end_date = df.EndTS.max()
end_date = start_date + np.timedelta64(6,"M")

# %%
print("generators in germany in dataset:",np.sum(gen_info["MapCode"] == "DE"))
print("generators in germany in generated scenarios:", np.sum(geo.Country == "Germany"))
# Out:
# generators in germany in dataset: 233
# generators in germany in generated scenarios: 85

# %%
geo.columns
# Out:
# Index(['Name', 'Fueltype', 'Technology', 'Set', 'Country', 'Capacity',
#        'Efficiency', 'DateIn', 'DateRetrofit', 'DateOut', 'lat', 'lon',
#        'Duration', 'Volume_Mm3', 'DamHeight_m', 'StorageCapacity_MWh', 'EIC',
#        'projectID'],
#       dtype='object', name='GEO')

# %%
#convert to pypsa format
#check for first event correctness
df = df.sort_values(["UnitName","StartTS"])
scenarios_d = {}
for gen, gen_df in df.groupby("UnitName"):
    gen_scenario = []
    current_date = start_date
    #we assume df is sorted by startTS
    
    for index, event in gen_df.iterrows():
        if event.EndTS <= end_date:
            hours_before_event = int((event["StartTS"] - current_date) / np.timedelta64(1,"h"))
            gen_scenario += [1] * hours_before_event
            duration_event = int((event["EndTS"] - event["StartTS"]) / np.timedelta64(1,"h"))
            pu = event["p.u."]
            gen_scenario += [pu] * duration_event
            current_date = event["EndTS"]
        elif event.StartTS <= end_date:
            hours_before_event = int((event["StartTS"] - current_date) / np.timedelta64(1,"h"))
            gen_scenario += [1] * hours_before_event
            duration_event = int((end_date - event["StartTS"]) / np.timedelta64(1,"h"))
            pu = event["p.u."]
            gen_scenario += [pu] * duration_event
            current_date = end_date
            break
        else:
            break
        
    last_hours = int((end_date - current_date) / np.timedelta64(1,"h"))
    gen_scenario += [1]*last_hours
    scenarios_d[gen] = gen_scenario


min_l = 50000
for key, value in scenarios_d.items():
    if len(value) < min_l:
        min_l = len(value)
for key, value in scenarios_d.items():
    scenarios_d[key] = scenarios_d[key][:min_l]

# %%
timestamp = []
for h in np.arange(min_l):
    timestamp += [start_date + np.timedelta64(h,"h")]
scenarios_d["TimeStamp"] = timestamp
data_scenario = pd.DataFrame(scenarios_d)

# %%
gen_series = pd.Series(data_scenario.set_index("TimeStamp").columns)
gen_info = df.groupby("UnitName").first().reset_index()
data_scenario.set_index("TimeStamp").groupby(
    [
        gen_series.map(gen_info.set_index("UnitName").MapCode).values,
        gen_series.map(gen_info.set_index("UnitName").ProductionType).values,
    ],
    axis=1
).mean()["DE"].plot()
# Out:
# <Axes: xlabel='TimeStamp'>

# %%
df.columns
# Out:
# Index(['StartTS', 'EndTS', 'TimeZone', 'Status', 'Type', 'AreaCode',
#        'AreaTypeCode', 'AreaName', 'MapCode', 'PowerResourceEIC', 'UnitName',
#        'ProductionType', 'InstalledCapacity', 'AvailableCapacity', 'Version',
#        'Reason', 'UpTime', 'ForcedTime', 'PlannedTime', 'RunningTime', 'p.u.'],
#       dtype='object')

# %%
df
# Out:
#                    StartTS               EndTS TimeZone     Status     Type  \
# 266143 2014-12-01 00:00:00 2015-01-22 00:00:00      WET     Active  Planned
# 142453 2014-12-01 00:00:00 2015-01-02 11:30:00      WET  Withdrawn  Planned
# 454211 2014-12-01 01:00:00 2014-12-09 00:00:00      CET     Active   Forced
# 482619 2014-12-01 02:00:00 2015-02-06 00:00:00      CET     Active   Forced
# 97966  2014-12-01 02:51:00 2014-12-01 03:48:00      WET     Active   Forced
# ...                    ...                 ...      ...        ...      ...
# 355518 2030-01-11 23:00:00 2030-01-14 07:00:00      WET     Active  Planned
# 355519 2030-03-08 23:00:00 2030-03-11 07:00:00      WET     Active  Planned
# 355520 2030-05-10 23:00:00 2030-06-14 07:00:00      WET     Active  Planned
# 306882 2030-06-30 08:00:00 2030-06-30 09:30:00      CET     Active  Planned
# 355521 2030-07-12 23:00:00 2030-07-15 07:00:00      WET     Active  Planned
#
#                 AreaCode AreaTypeCode               AreaName MapCode  \
# 266143  10YGB----------A          BZN                 GB BZN      GB
# 142453  10YGB----------A          BZN                 GB BZN      GB
# 454211  10YPT-REN------W          CTA                 PT CTA      PT
# 482619  10YPL-AREA-----S          CTA                 PL CTA      PL
# 97966   10YGB----------A          CTA  UK(National Grid) CTA      GB
# ...                  ...          ...                    ...     ...
# 355518  10YGB----------A          CTA  UK(National Grid) CTA      GB
# 355519  10YGB----------A          BZN                 GB BZN      GB
# 355520  10YGB----------A          CTA  UK(National Grid) CTA      GB
# 306882  10Y1001A1001A44P          BZN                SE1 BZN      SE
# 355521  10YGB----------A          CTA  UK(National Grid) CTA      GB
#
#         PowerResourceEIC  ...                    ProductionType  \
# 266143  48W000000HRTL-16  ...                          Nuclear
# 142453  48W00000EGGPS-2V  ...                 Fossil Hard coal
# 454211  16WREGUA1------8  ...  Hydro Run-of-river and poundage
# 482619  19W000000000184V  ...                 Fossil Hard coal
# 97966   48W00000DRAXX-2C  ...                          Biomass
# ...                  ...  ...                               ...
# 355518  48W000000LBAR-1Y  ...                       Fossil Gas
# 355519  48W000000LBAR-1Y  ...                       Fossil Gas
# 355520  48W000000LBAR-1Y  ...                       Fossil Gas
# 306882  46WGU0000000028T  ...            Hydro Water Reservoir
# 355521  48W000000LBAR-1Y  ...                       Fossil Gas
#
#        InstalledCapacity  AvailableCapacity  Version  \
# 266143             666.0              451.0        1
# 142453             525.0                0.0        3
# 454211              60.0                0.0        1
# 482619             128.0                0.0        2
# 97966              645.0              615.0        1
# ...                  ...                ...      ...
# 355518             735.0                0.0        2
# 355519             735.0                0.0        2
# 355520             735.0                0.0        2
# 306882             440.0                0.0        1
# 355521             735.0                0.0        1
#
#                            Reason              UpTime ForcedTime  PlannedTime  \
# 266143  Complementary Information                 NaN        NaN       1248.0
# 142453       Foreseen Maintenance                 NaN        NaN        779.5
# 454211                    Failure                 NaN     191.00          NaN
# 482619                    Failure                 NaN    1606.00          NaN
# 97966                     Failure                 NaN       0.95          NaN
# ...                           ...                 ...        ...          ...
# 355518       Foreseen Maintenance    91 days 00:00:00        NaN         56.0
# 355519       Foreseen Maintenance    56 days 00:00:00        NaN         56.0
# 355520       Foreseen Maintenance    63 days 00:00:00        NaN        824.0
# 306882       Foreseen Maintenance  2869 days 01:00:00        NaN          1.5
# 355521       Foreseen Maintenance    63 days 00:00:00        NaN         56.0
#
#         RunningTime      p.u.
# 266143          NaN  0.677177
# 142453          NaN  0.000000
# 454211          NaN  0.000000
# 482619          NaN  0.000000
# 97966           NaN  0.953488
# ...             ...       ...
# 355518       2128.0  0.000000
# 355519       1288.0  0.000000
# 355520       1456.0  0.000000
# 306882      68752.0  0.000000
# 355521        688.0  0.000000
#
# [454256 rows x 21 columns]

# %%
df["UnitName"]
# Out:
# 0         ABO¿O 1
# 1         ABO¿O 1
# 2         ABO¿O 1
# 4         ABO¿O 1
# 6         ABO¿O 1
#            ...
# 573766      ÚJ_ST
# 573767      ÚJ_ST
# 573769      ÚJ_ST
# 573771      ÚJ_ST
# 573772      ÚJ_ST
# Name: UnitName, Length: 454256, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 pu
#
# NameError: name 'pu' is not defined
